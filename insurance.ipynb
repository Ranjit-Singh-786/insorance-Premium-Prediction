# %%
import pandas as pd
import json
import os,sys
from pathlib import Path
from typing import Optional
import logging
import numpy as np

# %%
FILE_PATH = (r"C:\Users\Ranjit Singh\Desktop\insorance-Premium-Prediction\insurance.csv")
df = pd.read_csv(FILE_PATH)
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
transfomed_data_file_path =r'C:\Users\Ranjit Singh\Desktop\insorance-Premium-Prediction\artifacts\02052023__211653\DataTransformation\transformed\train.npz'

# %% [markdown]
# Transformed_data

# %%
tfdf = pd.DataFrame(np.load(transfomed_data_file_path),columns=df.columns)
tfdf.head()
# this is happened by the np.c_
# Out:
#         age  sex       bmi  children  smoker  region      charges
# 0 -0.791667 -1.0 -1.015082      -0.5     0.0    -2.0   2585.85065
# 1 -0.125000  0.0  0.060942       1.0     0.0    -1.0   6796.86325
# 2  0.750000 -1.0  0.334872      -0.5     0.0     1.0  11848.14100
# 3 -0.750000 -1.0 -0.886427      -0.5     0.0    -2.0   2731.91220
# 4  0.333333 -1.0  0.227762       0.0     0.0     0.0   8871.15170

# %%
tfdf['region'].value_counts()
# Out:
#  0.0    293
#  1.0    262
# -2.0    259
# -1.0    256
# Name: region, dtype: int64

# %%
tfdf['sex'].value_counts()
# Out:
#  0.0    545
# -1.0    525
# Name: sex, dtype: int64

# %%
tfdf['smoker'].value_counts()
# Out:
# 0.0    851
# 1.0    219
# Name: smoker, dtype: int64

# %%
tfdf['children'].value_counts()
# Out:
# -0.5    446
#  0.0    263
#  0.5    194
#  1.0    135
#  1.5     18
#  2.0     14
# Name: children, dtype: int64

# %%
df['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df[]

# %%
pd.DataFrame(np.c_[df[['charges','age']].values])
# Out:
#                 0     1
# 0     16884.92400  19.0
# 1      1725.55230  18.0
# 2      4449.46200  28.0
# 3     21984.47061  33.0
# 4      3866.85520  32.0
# ...           ...   ...
# 1333  10600.54830  50.0
# 1334   2205.98080  18.0
# 1335   1629.83350  18.0
# 1336   2007.94500  21.0
# 1337  29141.36030  61.0
#
# [1338 rows x 2 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.var()
# Out:
# C:\Users\Ranjit Singh\AppData\Local\Temp\ipykernel_3360\1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# age         1.974014e+02
# bmi         3.718788e+01
# children    1.453213e+00
# charges     1.466524e+08
# dtype: float64

# %%
df['age'].squeeze()
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
from scipy.stats import ks_2samp

# %%
df[df['charges']=='na']
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %%
try:
    5/0
except :
    a,b,c = sys.exc_info()
    print(c)

# %%
while True:
    project_name = input("Enter your project name: ")
    if project_name !='':
        break

logging.info(f"Creating project by name: {project_name}")

list_of_files = [
    ".github/workflows/.gitkeep",
    ".github/workflows/main.yaml",
   # f"src/{project_name}/__init__.py",
    f"{project_name}/__init__.py",
    f"{project_name}/components/__init__.py",
    f"{project_name}/entity/__init__.py",
    f"{project_name}/pipeline/__init__.py",
    f"{project_name}/logger/__init__.py",
    f"{project_name}/config.py",
    f"{project_name}/exception.py",
    f"{project_name}/predictor.py",
    f"{project_name}/utils.py",
    f"configs/config.yaml",
    "requirements.txt",
    "setup.py",
    "main.py"
]


for filepath in list_of_files:
    filepath = Path(filepath)
    filedir, filename = os.path.split(filepath)
    if filedir !="":
        os.makedirs(filedir, exist_ok=True)
        logging.info(f"Creating a new directory at : {filedir} for file: {filename}")
    if (not os.path.exists(filepath)) or (os.path.getsize(filepath) == 0):
        with open(filepath, "w") as f:
            pass
            logging.info(f"Creating a new file: {filename} for path: {filepath}")
    else:
        logging.info(f"file is already present at: {filepath}")

# %%
project_name = 'insorance'
list_of_files = [
    ".github/workflows/.gitkeep",
    ".github/workflows/main.yaml",
   # f"src/{project_name}/__init__.py",
    f"{project_name}/__init__.py",
    f"{project_name}/components/__init__.py",
    f"{project_name}/entity/__init__.py",
    f"{project_name}/pipeline/__init__.py",
    f"{project_name}/logger/__init__.py",
    f"{project_name}/config.py",
    f"{project_name}/exception.py",
    f"{project_name}/predictor.py",
    f"{project_name}/utils.py",
    f"configs/config.yaml",
    "requirements.txt",
    "setup.py",
    "main.py"
]

# %%
list_of_files
# Out:
# ['.github/workflows/.gitkeep',
#  '.github/workflows/main.yaml',
#  'insorance/__init__.py',
#  'insorance/components/__init__.py',
#  'insorance/entity/__init__.py',
#  'insorance/pipeline/__init__.py',
#  'insorance/logger/__init__.py',
#  'insorance/config.py',
#  'insorance/exception.py',
#  'insorance/predictor.py',
#  'insorance/utils.py',
#  'configs/config.yaml',
#  'requirements.txt',
#  'setup.py',
#  'main.py']

# %%
for filepath in list_of_files:
    filepath = Path(filepath)
    # print(filepath)
    filedir, filename = os.path.split(filepath)
    print(f"Filedirectory {filedir} ")
    print(f"filenames {filename} \n")
# Out:
# Filedirectory .github/workflows
# filenames .gitkeep
#
# Filedirectory .github/workflows
# filenames main.yaml
#
# Filedirectory insorance
# filenames __init__.py
#
# Filedirectory insorance/components
# filenames __init__.py
#
# Filedirectory insorance/entity
# filenames __init__.py
#
# Filedirectory insorance/pipeline
# filenames __init__.py
#
# Filedirectory insorance/logger
# filenames __init__.py
#
# Filedirectory insorance
# filenames config.py
#
# Filedirectory insorance
# filenames exception.py
#
# Filedirectory insorance
# filenames predictor.py
#
# Filedirectory insorance
# filenames utils.py
#
# Filedirectory configs
# filenames config.yaml
#
# Filedirectory
# filenames requirements.txt
#
# Filedirectory
# filenames setup.py
#
# Filedirectory
# filenames main.py

# %%
df.reset_index(drop=True,inplace=True)

# %%
list(json.loads(df.T.to_json()).values())
# Out:
# [{'age': 19,
#   'sex': 'female',
#   'bmi': 27.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'charges': 16884.924},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 33.77,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'charges': 1725.5523},
#  {'age': 28,
#   'sex': 'male',
#   'bmi': 33.0,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'charges': 4449.462},
#  {'age': 33,
#   'sex': 'male',
#   'bmi': 22.705,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'charges': 21984.47061},
#  {'age': 32,
#   'sex': 'male',
#   'bmi': 28.88,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'charges': 3866.8552},
#  {'age': 31,
#   'sex': 'female',
#   'bmi': 25.74,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'charges': 3756.6216},
#  {'age': 46,
#   'sex': 'female',
#   'bmi': 33.44,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
# ...

# %%
requirement_filePath = 'requirements.txt'
editable_indiacator = '-e .'
def get_requirements()->list[str]:
    with open(requirement_filePath) as requirementFile:
        requirement_list = requirementFile.readlines()
    requirement_list = [requirement.replace("\n","") for requirement in requirement_list]
    if editable_indiacator in requirement_list:
        requirement_list.remove(editable_indiacator)
    return requirement_list

# %%
get_requirements()
# Out:
# ['pandas', 'numpy', 'pymongo']

# %%
import sys

# %%
try:
    2/0
except Exception as e:
    # print(e)
    a,b,c= sys.exc_info()
    print(a)
    print(b)

    print(c.tb_next)
    print(c.tb_frame.f_lineno)
    print(c.tb_frame.f_code.co_filename)
    print(b)


    print('hell')
# Out:
# <class 'ZeroDivisionError'>
# division by zero
# None
# 10
# C:\Users\Ranjit Singh\AppData\Local\Temp\ipykernel_7444\2895540016.py
# division by zero
# hell

# %%
def get_latest_dir_path()->Optional[str]:
    try:
        dir_name = os.listdir('saved_models')
        if len(dir_name) == 0:
            return None
        
        dir_name = list(map(int, dir_name)) # int means it will take just integer value in the listdir
        latest_dir_name = max(dir_name)
        return os.path.join('saved_models', f"{latest_dir_name}")

    except Exception as e:
        raise e

# %%
print(get_latest_dir_path())
# Out:
# None

# %%
os.path.join(os.getcwd(),'a')
# Out:
# 'c:\\Users\\Ranjit Singh\\Desktop\\insorance-Premium-Prediction\\a'

# %%
dir_name = os.listdir('saved_models')
dir_name
# Out:
# []

# %%
dir_name = list(map(int, dir_name))
dir_name
# Out:
# []

# %%
def a():
    if True:
        return 5/2
    print('second')

# %%
print(a())
# Out:
# 2.5
